# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.chdir(r"C:\Users\hanis\OneDrive\Desktop\Kamakshigari Hanish FWI")

import pandas as pd
data = pd.read_csv("train_data.csv")

# %%
data
# Out:
#               report_date  temperature  dew_point_temperature  \
# 0        27-08-2019 12:00         12.0                    7.6
# 1        06-06-2018 12:00         11.1                    1.7
# 2        11-10-2014 12:00          2.9                    2.3
# 3        11-09-2015 12:00         22.1                   11.1
# 4        22-06-2016 12:00         17.0                   10.0
# ...                   ...          ...                    ...
# 1048570  02-10-2017 12:00         11.1                   -0.8
# 1048571  20-09-2014 12:00          9.2                    4.1
# 1048572  16-09-2019 12:00         16.0                   11.0
# 1048573  14-07-2018 12:00         26.1                   21.7
# 1048574  28-05-2017 12:00         19.0                    9.0
#
#          relative_humidity  wind_speed  wind_direction  atmospheric_pressure  \
# 0                     74.4        12.0               0               1015.13
# ...

# %%
data.columns
# Out:
# Index(['report_date', 'temperature', 'dew_point_temperature',
#        'relative_humidity', 'wind_speed', 'wind_direction',
#        'atmospheric_pressure', 'visibility', 'precipitation', 'rain_days',
#        'snow_on_ground', 'fine_fuel_moisture_code', 'duff_moisture_code',
#        'drought_code', 'build_up_index', 'initial_spread_index',
#        'fire_weather_index', 'daily_severity_rating', 'country', 'latitude',
#        'longitude', 'elevation'],
#       dtype='object')

# %%
data['FFMC__TEMP'] = data['temperature'] * data['fine_fuel_moisture_code']
data['FFMC_RH'] = data['relative_humidity'] * data['fine_fuel_moisture_code']
data['RH_TEMP'] = data['temperature'] * data['relative_humidity']
data['RD_FFMC'] = data['fine_fuel_moisture_code'] * data['rain_days']
data['DC_RD'] = data['drought_code'] * data['rain_days']
data['WS_TENP'] = data['wind_speed'] * data['fine_fuel_moisture_code']
data['IST_WS'] = data['wind_speed'] * data['initial_spread_index']
data['ISI_FFMC'] = data['initial_spread_index'] * data['fine_fuel_moisture_code']
data['ISI_RH'] = data['initial_spread_index'] * data['relative_humidity']
data['DMC_TEMP'] = data['duff_moisture_code'] * data['temperature']
data['DMC_RD'] = data['duff_moisture_code'] * data['rain_days']
data['RD_TEMP'] = data['rain_days'] * data['temperature']
data['DMC_DC'] = data['drought_code'] * data['duff_moisture_code']
data['BUI_DC'] = data['drought_code'] * data['build_up_index']
data['BUI_DMC'] = data['duff_moisture_code'] * data['build_up_index']

# %%
data
# Out:
#               report_date  temperature  dew_point_temperature  \
# 0        27-08-2019 12:00         12.0                    7.6
# 1        06-06-2018 12:00         11.1                    1.7
# 2        11-10-2014 12:00          2.9                    2.3
# 3        11-09-2015 12:00         22.1                   11.1
# 4        22-06-2016 12:00         17.0                   10.0
# ...                   ...          ...                    ...
# 1048570  02-10-2017 12:00         11.1                   -0.8
# 1048571  20-09-2014 12:00          9.2                    4.1
# 1048572  16-09-2019 12:00         16.0                   11.0
# 1048573  14-07-2018 12:00         26.1                   21.7
# 1048574  28-05-2017 12:00         19.0                    9.0
#
#          relative_humidity  wind_speed  wind_direction  atmospheric_pressure  \
# 0                     74.4        12.0               0               1015.13
# ...

# %%
df_encoded = pd.get_dummies(data, columns=['country'], dtype=int)

# %%
df_encoded
# Out:
#               report_date  temperature  dew_point_temperature  \
# 0        27-08-2019 12:00         12.0                    7.6
# 1        06-06-2018 12:00         11.1                    1.7
# 2        11-10-2014 12:00          2.9                    2.3
# 3        11-09-2015 12:00         22.1                   11.1
# 4        22-06-2016 12:00         17.0                   10.0
# ...                   ...          ...                    ...
# 1048570  02-10-2017 12:00         11.1                   -0.8
# 1048571  20-09-2014 12:00          9.2                    4.1
# 1048572  16-09-2019 12:00         16.0                   11.0
# 1048573  14-07-2018 12:00         26.1                   21.7
# 1048574  28-05-2017 12:00         19.0                    9.0
#
#          relative_humidity  wind_speed  wind_direction  atmospheric_pressure  \
# 0                     74.4        12.0               0               1015.13
# ...

# %%
df_encoded.columns
# Out:
# Index(['report_date', 'temperature', 'dew_point_temperature',
#        'relative_humidity', 'wind_speed', 'wind_direction',
#        'atmospheric_pressure', 'visibility', 'precipitation', 'rain_days',
#        'snow_on_ground', 'fine_fuel_moisture_code', 'duff_moisture_code',
#        'drought_code', 'build_up_index', 'initial_spread_index',
#        'fire_weather_index', 'daily_severity_rating', 'latitude', 'longitude',
#        'elevation', 'FFMC__TEMP', 'FFMC_RH', 'RH_TEMP', 'RD_FFMC', 'DC_RD',
#        'WS_TENP', 'IST_WS', 'ISI_FFMC', 'ISI_RH', 'DMC_TEMP', 'DMC_RD',
#        'RD_TEMP', 'DMC_DC', 'BUI_DC', 'BUI_DMC', 'country_Canada',
#        'country_France', 'country_Spain', 'country_United Kingdom',
#        'country_United States'],
#       dtype='object')

# %%
data = df_encoded

# %%
data.columns
# Out:
# Index(['report_date', 'temperature', 'dew_point_temperature',
#        'relative_humidity', 'wind_speed', 'wind_direction',
#        'atmospheric_pressure', 'visibility', 'precipitation', 'rain_days',
#        'snow_on_ground', 'fine_fuel_moisture_code', 'duff_moisture_code',
#        'drought_code', 'build_up_index', 'initial_spread_index',
#        'fire_weather_index', 'daily_severity_rating', 'latitude', 'longitude',
#        'elevation', 'FFMC__TEMP', 'FFMC_RH', 'RH_TEMP', 'RD_FFMC', 'DC_RD',
#        'WS_TENP', 'IST_WS', 'ISI_FFMC', 'ISI_RH', 'DMC_TEMP', 'DMC_RD',
#        'RD_TEMP', 'DMC_DC', 'BUI_DC', 'BUI_DMC', 'country_Canada',
#        'country_France', 'country_Spain', 'country_United Kingdom',
#        'country_United States'],
#       dtype='object')

# %%
data.shape
# Out:
# (1048575, 41)
